# %% [markdown]
# # openaiのインストール

# %%
# !pip install openai

# %% [markdown]
# # APIを呼び出して応答を得る関数を定義

# %%
import openai
openai.api_key = "YOUR_API_KEY"

def ask_chatgpt(prompt):
    response = openai.Completion.create(
      engine="davinci",
      prompt=prompt,
      max_tokens=1024,
      n=1,
      stop=None,
      temperature=0.7,
    )

    message = response.choices[0].text
    return message.strip()

# %% [markdown]
# # 定義した関数を使って質問してみる

# %%
response = ask_chatgpt("データ分析コンペのいいところ")
print(response)
